# %% [markdown]
# ## Overall performance comparasion:
#
# Data: 55000 training data, 5000 validation data, 10000 test data;
# Step up: 5 layers with 100 node on each layer.
#
# Batch GD: waist a lot of time to converge. It needed 2000 step to have similar performance of mini-batch.
#
#     time consumption: 1484.6108751296997
#     performance score: 0.865
#
# mini-batch GD:
#
#     time consumption: 89.35848474502563
#     performance score: 0.9733
# Adam:
#
#     time consumption:  114.90625596046448
#     performance score:   0.1998
#
# Adam with earily stoping: (35% threshold stop)
#
#     time consumption: 51.90262746810913
#     performance score: 0.9

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "deep"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %%
import tensorflow as tf
import numpy as np

# %%
(X_data, y_data), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
print (X_data.shape)
# reduce the dimention of X_train, X_test
def reduce_D (data):
    return data.astype (np.float32).reshape (-1, 28 * 28) / 255.0
X_data, X_test = reduce_D  (X_data), reduce_D (X_test)
print (X_data.shape, X_test.shape)

# Check Y :
# print (y_data.shape)
# def y_preprocess (data):
#     return data.astype (np.int32).reshape (data.shape[0], 1)
# y_data, y_test = y_preprocess (y_data), y_preprocess (y_test)
print (y_data.shape, y_test.shape)

# split the train and validation data:
X_validation, y_validation = X_data[:5000], y_data[:5000]
X_train, y_train = X_data[5000:], y_data[5000:]

print (X_validation.shape, X_train.shape, y_validation.shape)
# Out:
# (60000, 28, 28)
# (60000, 784) (10000, 784)
# (60000,) (10000,)
# (5000, 784) (55000, 784) (5000,)

# %% [markdown]
# ## Regular GD

# %% [markdown]
# Step up: 5 layers with 100 nodes on each layer, mini-batch size is 32, train 20 steps.
#
# Performance evaluation:
#
#     time consumption: 89.35848474502563
#     performance score: 0.9733

# %%
N_feature = X_test.shape[1]
n_layers = 5
n_neurons = 100
learning_rate = 0.01
n_output = 10

# %%
X = tf.placeholder (tf.float32, shape = (None, N_feature), name = 'X')
y = tf.placeholder (tf.int32, shape = (None), name = 'y')

# %%
with tf.name_scope ('DNN_chapter11_8'):
    he_init = tf.contrib.layers.variance_scaling_initializer ()
    hidden1 = tf.layers.dense (X, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden1')
    hidden2 = tf.layers.dense (hidden1, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden2')
    hidden3 = tf.layers.dense (hidden2, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden3')
    hidden4 = tf.layers.dense (hidden3, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden4')
    hidden5 = tf.layers.dense (hidden4, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden5')
    y_predit = tf.layers.dense (hidden5, n_output, kernel_initializer = he_init, name = 'Output')
    y_proba = tf.nn.softmax (y_predit, name = "y_predit")

# %%
with tf.name_scope ('loss'):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=y_predit)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(y_predit, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
n_steps = 20
batch_size = 32
data_size = X_train.shape[0]
n_batch = int (np.ceil (data_size / batch_size))

# %%
import time

# %%
with tf.Session() as sess:
    init.run()
    total_start_time = time.time()
    for step in range (n_steps):
        start_time = time.time ()
        for i_batch in range (n_batch):
            start = i_batch * batch_size
            if i_batch != n_batch - 1:
                end = start + batch_size
            else:
                end = data_size
            sess.run (training_op, feed_dict = {X: X_data[start: end], y: y_data[start: end]})
        train_score = accuracy.eval (feed_dict = {X: X_data[start: end], y: y_data[start: end]})
        validation_score = accuracy.eval (feed_dict = {X: X_validation, y:y_validation})
        end_time = time.time ()
        run_time = end_time - start_time
        print ('At step ', step, 'the train_score is ', train_score, 'the validation score is ', validation_score, 'this cost', run_time)
    total_end_time = time.time ()
    accuracy_val = accuracy.eval (feed_dict = {X: X_test, y: y_test})
    print ('Run', n_steps,  'steps total process time is',  total_end_time - total_start_time)
    print ('the test set accuracy is', accuracy_val)
# Out:
# At step  0 the train_score is  0.9166667 the validation score is  0.9386 this cost 4.622397422790527
# At step  1 the train_score is  0.9166667 the validation score is  0.957 this cost 4.453064918518066
# At step  2 the train_score is  1.0 the validation score is  0.9644 this cost 4.459587097167969
# At step  3 the train_score is  1.0 the validation score is  0.9686 this cost 4.455009937286377
# At step  4 the train_score is  1.0 the validation score is  0.972 this cost 4.459731817245483
# At step  5 the train_score is  1.0 the validation score is  0.975 this cost 4.4487059116363525
# At step  6 the train_score is  1.0 the validation score is  0.976 this cost 4.45017147064209
# At step  7 the train_score is  1.0 the validation score is  0.9784 this cost 4.459004163742065
# At step  8 the train_score is  1.0 the validation score is  0.9822 this cost 4.527098178863525
# At step  9 the train_score is  1.0 the validation score is  0.9842 this cost 4.454243421554565
# At step  10 the train_score is  1.0 the validation score is  0.9874 this cost 4.460422992706299
# At step  11 the train_score is  1.0 the validation score is  0.9878 this cost 4.452265977859497
# At step  12 the train_score is  1.0 the validation score is  0.9882 this cost 4.454642057418823
# At step  13 the train_score is  1.0 the validation score is  0.989 this cost 4.460584402084351
# At step  14 the train_score is  1.0 the validation score is  0.99 this cost 4.447627544403076
# At step  15 the train_score is  1.0 the validation score is  0.9908 this cost 4.457718372344971
# At step  16 the train_score is  1.0 the validation score is  0.992 this cost 4.453486919403076
# At step  17 the train_score is  1.0 the validation score is  0.9926 this cost 4.459336757659912
# At step  18 the train_score is  1.0 the validation score is  0.993 this cost 4.468623399734497
# At step  19 the train_score is  1.0 the validation score is  0.9942 this cost 4.4527716636657715
# Run 20 steps total process time is 89.35848474502563
# the test set accuracy is 0.9733

# %%
reset_graph ()
N_feature = X_test.shape[1]
n_layers = 5
n_neurons = 100
learning_rate = 0.001
n_output = 10

# %% [markdown]
# ## Adam:
# Step up: 5 layers with 100 nodes on each layer, mini-batch size is 32, train 30 steps.
#
# Performance evaluation:
#
#     time consumption:  114.90625596046448
#     performance score:   0.1998
#
# Appearently there is an error in decent, it seems moved too fast and missed the lowest point, we shall introduce the earily stop tech.
# Idealy, at step 15 , you should stop the process. The train score dropped to  0.45833334 at step 15 same as validation score
#
# Change the learning rate to 0.001 could resolve this issue, although I still don't understand why

# %%
X = tf.placeholder (tf.float32, shape = (None, N_feature), name = 'X')
y = tf.placeholder (tf.int32, shape = (None), name = 'y')

# %%
with tf.name_scope ('DNN_chapter11_8'):
    he_init = tf.contrib.layers.variance_scaling_initializer ()
    hidden1 = tf.layers.dense (X, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden1')
    hidden2 = tf.layers.dense (hidden1, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden2')
    hidden3 = tf.layers.dense (hidden2, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden3')
    hidden4 = tf.layers.dense (hidden3, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden4')
    hidden5 = tf.layers.dense (hidden4, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden5')
    y_predit = tf.layers.dense (hidden5, n_output, kernel_initializer = he_init, name = 'Output')

# %%
with tf.name_scope ('loss'):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=y_predit)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
with tf.name_scope("train"):
    optimizer = tf.train.AdamOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(y_predit, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
n_steps = 20
batch_size = 32
data_size = X_train.shape[0]
n_batch = int (np.ceil (data_size / batch_size))

# %%
with tf.Session() as sess:
    init.run()
    total_start_time = time.time()
    for step in range (n_steps):
        start_time = time.time ()
        for i_batch in range (n_batch):
            start = i_batch * batch_size
            if i_batch != n_batch - 1:
                end = start + batch_size
            else:
                end = data_size
            sess.run (training_op, feed_dict = {X: X_train[start: end], y: y_train[start: end]})
        loss_train, train_score = sess.run ([loss, accuracy], feed_dict = {X: X_train[start: end], y: y_train[start: end]})
        loss_val, validation_score = sess.run([loss, accuracy], feed_dict = {X: X_validation, y:y_validation})
        end_time = time.time ()
        run_time = end_time - start_time
        print ('At step ', step, 'the train_score is ', train_score, 'the validation score is ', validation_score, 'this cost', run_time)
        print ('At step ', step, 'the loss is ', loss_val, 'the best loss is ', best_loss, 'this cost', run_time)
        print (loss_train)
    total_end_time = time.time ()
    accuracy_val = accuracy.eval (feed_dict = {X: X_test, y: y_test})
    print ('Run', n_steps,  'steps total process time is',  total_end_time - total_start_time)
    print ('the test set accuracy is', accuracy_val)
# Out:
# At step  0 the train_score is  1.0 the validation score is  0.9478 this cost 6.27926230430603
# At step  0 the loss is  0.17681785 the best loss is  1000 this cost 6.27926230430603
# 0.023942286
# At step  1 the train_score is  1.0 the validation score is  0.963 this cost 6.287681818008423
# At step  1 the loss is  0.13302934 the best loss is  1000 this cost 6.287681818008423
# 0.015892332
# At step  2 the train_score is  1.0 the validation score is  0.9698 this cost 6.267089128494263
# At step  2 the loss is  0.11656096 the best loss is  1000 this cost 6.267089128494263
# 0.0004148536
# At step  3 the train_score is  1.0 the validation score is  0.9704 this cost 6.497232913970947
# At step  3 the loss is  0.1071388 the best loss is  1000 this cost 6.497232913970947
# 0.0028896108
# At step  4 the train_score is  1.0 the validation score is  0.9628 this cost 6.320879697799683
# At step  4 the loss is  0.13623112 the best loss is  1000 this cost 6.320879697799683
# 0.00039440638
# At step  5 the train_score is  1.0 the validation score is  0.9658 this cost 6.424075365066528
# At step  5 the loss is  0.13784342 the best loss is  1000 this cost 6.424075365066528
# 0.0034237436
# At step  6 the train_score is  1.0 the validation score is  0.9694 this cost 6.251490116119385
# At step  6 the loss is  0.11769521 the best loss is  1000 this cost 6.251490116119385
# 8.5712345e-05
# At step  7 the train_score is  1.0 the validation score is  0.9668 this cost 6.722156524658203
# At step  7 the loss is  0.14892425 the best loss is  1000 this cost 6.722156524658203
# 0.0035803113
# At step  8 the train_score is  1.0 the validation score is  0.9776 this cost 6.426820516586304
# At step  8 the loss is  0.12030724 the best loss is  1000 this cost 6.426820516586304
# 4.5962905e-05
# At step  9 the train_score is  1.0 the validation score is  0.9722 this cost 6.206977367401123
# At step  9 the loss is  0.14791636 the best loss is  1000 this cost 6.206977367401123
# 0.002855449
# At step  10 the train_score is  1.0 the validation score is  0.9672 this cost 6.028230905532837
# At step  10 the loss is  0.17579743 the best loss is  1000 this cost 6.028230905532837
# 3.5387e-05
# At step  11 the train_score is  1.0 the validation score is  0.9758 this cost 6.199175119400024
# At step  11 the loss is  0.126088 the best loss is  1000 this cost 6.199175119400024
# 1.8033103e-05
# At step  12 the train_score is  1.0 the validation score is  0.9762 this cost 6.803740501403809
# At step  12 the loss is  0.13454501 the best loss is  1000 this cost 6.803740501403809
# 5.7691734e-05
# At step  13 the train_score is  1.0 the validation score is  0.9726 this cost 6.161314964294434
# At step  13 the loss is  0.1417585 the best loss is  1000 this cost 6.161314964294434
# 0.00013255593
# At step  14 the train_score is  1.0 the validation score is  0.972 this cost 6.594274282455444
# At step  14 the loss is  0.16091083 the best loss is  1000 this cost 6.594274282455444
# 0.00020215048
# At step  15 the train_score is  1.0 the validation score is  0.9774 this cost 6.1314709186553955
# At step  15 the loss is  0.12295232 the best loss is  1000 this cost 6.1314709186553955
# 0.0019267903
# At step  16 the train_score is  1.0 the validation score is  0.9748 this cost 5.883596420288086
# At step  16 the loss is  0.13479635 the best loss is  1000 this cost 5.883596420288086
# 9.788278e-05
# At step  17 the train_score is  1.0 the validation score is  0.9694 this cost 6.675349235534668
# At step  17 the loss is  0.18192632 the best loss is  1000 this cost 6.675349235534668
# 0.00019269966
# At step  18 the train_score is  1.0 the validation score is  0.979 this cost 6.586137533187866
# At step  18 the loss is  0.12857278 the best loss is  1000 this cost 6.586137533187866
# 1.22619995e-05
# At step  19 the train_score is  1.0 the validation score is  0.9754 this cost 6.366391181945801
# At step  19 the loss is  0.14381137 the best loss is  1000 this cost 6.366391181945801
# 1.8980092e-05
# Run 20 steps total process time is 127.12333703041077
# the test set accuracy is 0.9771

# %% [markdown]
# ## Adam with early stop:
#
# Step up: 5 layers with 100 nodes on each layer, mini-batch size is 32, train 20 steps. earily stop if the loss not been reduced further for 35% of the steps.(at step 2, it seems randomly find a good result so stop earily)
#
# Performance evaluation:
#
#     time consumption: 51.90262746810913
#     performance score: 0.9
#
# Step up: 5 layers with 100 nodes on each layer, mini-batch size is 32, train 20 steps. earily stop if the loss not been reduced further for 30% of the steps.
#
# Performance evaluation:
#
#     time consumption: 61.913670778274536
#     performance score: 0.8656

# %%
reset_graph ()

X = tf.placeholder (tf.float32, shape = (None, N_feature), name = 'X')
y = tf.placeholder (tf.int32, shape = (None), name = 'y')

with tf.name_scope ('DNN_chapter11_8'):
    he_init = tf.contrib.layers.variance_scaling_initializer ()
    hidden1 = tf.layers.dense (X, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden1')
    hidden2 = tf.layers.dense (hidden1, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden2')
    hidden3 = tf.layers.dense (hidden2, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden3')
    hidden4 = tf.layers.dense (hidden3, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden4')
    hidden5 = tf.layers.dense (hidden4, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden5')
    y_predit = tf.layers.dense (hidden5, n_output, kernel_initializer = he_init, name = 'Output')

with tf.name_scope ('loss'):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=y_predit)
    loss = tf.reduce_mean(xentropy, name="loss")

with tf.name_scope("train"):
    optimizer = tf.train.AdamOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(y_predit, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()
saver = tf.train.Saver()
n_steps = 20
batch_size = 32
data_size = X_train.shape[0]
n_batch = int (np.ceil (data_size / batch_size))

with tf.Session() as sess:
    init.run()
    total_start_time = time.time()
    best_loss = 1000 
    without_update_counter = 0
    max_without_update = int (0.35 * n_steps)
    for step in range (n_steps):
        start_time = time.time ()
        for i_batch in range (n_batch):
            start = i_batch * batch_size
            if i_batch != n_batch - 1:
                end = start + batch_size
            else:
                end = data_size
            sess.run (training_op, feed_dict = {X: X_train[start: end], y: y_train[start: end]})
        train_score = accuracy.eval (feed_dict = {X: X_train[start: end], y: y_train[start: end]})
        loss_val, validation_score = sess.run([loss, accuracy], feed_dict = {X: X_validation, y:y_validation})
        end_time = time.time ()
        run_time = end_time - start_time
        print ('At step ', step, 'the train_score is ', train_score, 'the validation score is ', validation_score, 'this cost', run_time)
        print ('At step ', step, 'the loss is ', loss_val, 'the best loss is ', best_loss, 'this cost', run_time)
        if loss_val < best_loss:
            save_path = saver.save (sess, r'C:\Users\asiaynrf\Project\model_saver\my_model.ckpt')
            best_loss = loss_val
            without_update_counter = 0
        else:
            without_update_counter += 1
            if without_update_counter > max_without_update:
                print ('earily stopped')
                break
    total_end_time = time.time ()
    print ('Run', n_steps,  'steps total process time is',  total_end_time - total_start_time)

with tf.Session() as sess:
    saver.restore (sess, r'C:\Users\asiaynrf\Project\model_saver\my_model.ckpt')
    accuracy_val = accuracy.eval (feed_dict = {X: X_test, y: y_test})
    print ('the test set accuracy is', accuracy_val)

# %% [markdown]
# ## GD without mini-batch
# Performance evaluation:
#
# Score: (fogot to run the test set) 2000 steps's validation score is  0.9448. For the previous setup, it is 32 batch size, in another word, one step is an 1719 steps, so 20 step is 34380 steps in total. No wonder why mini-batch is better.
#
# Take look at the time consumption, it is 1468s, compare to 120s in previous method to have similar (actually worse) performance.
#
# time consume: 1483.5600037574768

# %%
reset_graph()

# %%
X = tf.placeholder (tf.float32, shape = (None, N_feature), name = 'X')
y = tf.placeholder (tf.int32, shape = (None), name = 'y')

# %%
with tf.name_scope ('DNN_chapter11_8'):
    he_init = tf.contrib.layers.variance_scaling_initializer ()
    hidden1 = tf.layers.dense (X, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden1')
    hidden2 = tf.layers.dense (hidden1, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden2')
    hidden3 = tf.layers.dense (hidden2, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden3')
    hidden4 = tf.layers.dense (hidden3, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden4')
    hidden5 = tf.layers.dense (hidden4, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name = 'Hidden5')
    y_predit = tf.layers.dense (hidden5, n_output, kernel_initializer = he_init, name = 'Output')

# %%
with tf.name_scope ('loss'):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=y_predit)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(y_predit, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()
n_steps = 2000
batch_size = 32
data_size = X_train.shape[0]
n_batch = int (np.ceil (data_size / batch_size))

# %%
with tf.Session() as sess:
    init.run()
    total_start_time = time.time()
    best_loss = 1000 
    without_update_counter = 0
    max_without_update = int (0.2 * n_steps)
    for step in range (n_steps):
        start_time = time.time ()
        sess.run (training_op, feed_dict = {X: X_train, y: y_train})
        train_score = accuracy.eval (feed_dict = {X: X_train, y: y_train})
        loss_val, validation_score = sess.run([loss, accuracy], feed_dict = {X: X_validation, y:y_validation})
        end_time = time.time ()
        run_time = end_time - start_time
        print ('At step ', step, 'the train_score is ', train_score, 'the validation score is ', validation_score, 'this cost', run_time)
        # print ('At step ', step, 'the loss is ', loss_val, 'the best loss is ', best_loss, 'this cost', run_time)
#         if loss_val < best_loss:
#             save_path = saver.save (sess, r'C:\Users\asiaynrf\Project\model_saver\my_model.ckpt')
#             best_loss = loss_val
#             without_update_counter = 0
#         else:
#             without_update_counter += 1
#             if without_update_counter > max_without_update:
#                 print ('earily stopped')
#                 break
    total_end_time = time.time ()
    print ('Run', n_steps,  'steps total process time is',  total_end_time - total_start_time)
    accuracy_val = accuracy.eval (feed_dict = {X: X_test, y: y_test})
    print ('the test set accuracy is', accuracy_val)
# Out:
# At step  0 the train_score is  0.085345455 the validation score is  0.0886 this cost 0.8102149963378906
# At step  1 the train_score is  0.08525454 the validation score is  0.0878 this cost 0.7481653690338135
# At step  2 the train_score is  0.085472725 the validation score is  0.0884 this cost 0.7392435073852539
# At step  3 the train_score is  0.085836366 the validation score is  0.0862 this cost 0.7626855373382568
# At step  4 the train_score is  0.08607273 the validation score is  0.0866 this cost 0.7516896724700928
# At step  5 the train_score is  0.086127274 the validation score is  0.0856 this cost 0.7467513084411621
# At step  6 the train_score is  0.08645455 the validation score is  0.086 this cost 0.758171796798706
# At step  7 the train_score is  0.08652727 the validation score is  0.0864 this cost 0.772463321685791
# At step  8 the train_score is  0.087290905 the validation score is  0.0862 this cost 0.7749936580657959
# At step  9 the train_score is  0.08769091 the validation score is  0.0862 this cost 0.7533373832702637
# At step  10 the train_score is  0.08796363 the validation score is  0.0858 this cost 0.7504615783691406
# At step  11 the train_score is  0.08874545 the validation score is  0.0868 this cost 0.7457799911499023
# At step  12 the train_score is  0.08918182 the validation score is  0.0872 this cost 0.7491626739501953
# At step  13 the train_score is  0.0904 the validation score is  0.0878 this cost 0.741610050201416
# At step  14 the train_score is  0.09134545 the validation score is  0.0902 this cost 0.7610490322113037
# At step  15 the train_score is  0.09254546 the validation score is  0.0906 this cost 0.7438750267028809
# At step  16 the train_score is  0.09369091 the validation score is  0.0916 this cost 0.7430980205535889
# At step  17 the train_score is  0.09489091 the validation score is  0.0932 this cost 0.7471036911010742
# At step  18 the train_score is  0.09576364 the validation score is  0.0932 this cost 0.7469818592071533
# At step  19 the train_score is  0.09729091 the validation score is  0.094 this cost 0.7431721687316895
# At step  20 the train_score is  0.09834545 the validation score is  0.096 this cost 0.7469680309295654
# At step  21 the train_score is  0.09965455 the validation score is  0.0972 this cost 0.7471609115600586
# At step  22 the train_score is  0.10107273 the validation score is  0.099 this cost 0.7533190250396729
# At step  23 the train_score is  0.10238182 the validation score is  0.101 this cost 0.7455201148986816
# At step  24 the train_score is  0.10374545 the validation score is  0.1024 this cost 0.7468209266662598
# At step  25 the train_score is  0.10529091 the validation score is  0.1042 this cost 0.7453136444091797
# At step  26 the train_score is  0.107 the validation score is  0.105 this cost 0.7540092468261719
# At step  27 the train_score is  0.10854545 the validation score is  0.1058 this cost 0.7496023178100586
# At step  28 the train_score is  0.11010909 the validation score is  0.1064 this cost 0.7427141666412354
# At step  29 the train_score is  0.11178182 the validation score is  0.1088 this cost 0.7451961040496826
# At step  30 the train_score is  0.11358182 the validation score is  0.1108 this cost 0.7490334510803223
# At step  31 the train_score is  0.11550909 the validation score is  0.1126 this cost 0.7478115558624268
# At step  32 the train_score is  0.11721818 the validation score is  0.1138 this cost 0.749284029006958
# At step  33 the train_score is  0.11907273 the validation score is  0.1152 this cost 0.7458705902099609
# At step  34 the train_score is  0.12078182 the validation score is  0.1182 this cost 0.7457773685455322
# At step  35 the train_score is  0.122763634 the validation score is  0.1206 this cost 0.7442057132720947
# At step  36 the train_score is  0.12507273 the validation score is  0.122 this cost 0.7536447048187256
# At step  37 the train_score is  0.1272 the validation score is  0.1232 this cost 0.7538132667541504
# At step  38 the train_score is  0.12929091 the validation score is  0.1256 this cost 0.7457489967346191
# At step  39 the train_score is  0.13129091 the validation score is  0.128 this cost 0.7472097873687744
# At step  40 the train_score is  0.1338 the validation score is  0.1302 this cost 0.7451624870300293
# At step  41 the train_score is  0.1360909 the validation score is  0.1326 this cost 0.7474198341369629
# At step  42 the train_score is  0.1382 the validation score is  0.1342 this cost 0.7521209716796875
# At step  43 the train_score is  0.14078182 the validation score is  0.1362 this cost 0.7589976787567139
# At step  44 the train_score is  0.14327273 the validation score is  0.1386 this cost 0.7495517730712891
# At step  45 the train_score is  0.14576364 the validation score is  0.1416 this cost 0.7508068084716797
# At step  46 the train_score is  0.148 the validation score is  0.1444 this cost 0.7462406158447266
# At step  47 the train_score is  0.15112728 the validation score is  0.1462 this cost 0.7456393241882324
# At step  48 the train_score is  0.1534 the validation score is  0.1498 this cost 0.7447350025177002
# At step  49 the train_score is  0.15592727 the validation score is  0.1516 this cost 0.7432405948638916
# At step  50 the train_score is  0.15836364 the validation score is  0.1532 this cost 0.7460179328918457
# At step  51 the train_score is  0.16105455 the validation score is  0.1566 this cost 0.7545239925384521
# At step  52 the train_score is  0.16378182 the validation score is  0.1582 this cost 0.7466037273406982
# At step  53 the train_score is  0.16627273 the validation score is  0.1596 this cost 0.7486443519592285
# At step  54 the train_score is  0.16907273 the validation score is  0.1626 this cost 0.7517542839050293
# At step  55 the train_score is  0.17196363 the validation score is  0.1658 this cost 0.7531478404998779
# At step  56 the train_score is  0.17461818 the validation score is  0.1698 this cost 0.7550880908966064
# At step  57 the train_score is  0.17765455 the validation score is  0.1736 this cost 0.7529947757720947
# At step  58 the train_score is  0.1804 the validation score is  0.1766 this cost 0.7546706199645996
# At step  59 the train_score is  0.18325454 the validation score is  0.1802 this cost 0.7623071670532227
# At step  60 the train_score is  0.18598182 the validation score is  0.183 this cost 0.7520339488983154
# At step  61 the train_score is  0.18909091 the validation score is  0.1854 this cost 0.7447915077209473
# At step  62 the train_score is  0.19212727 the validation score is  0.1884 this cost 0.7491679191589355
# At step  63 the train_score is  0.19525455 the validation score is  0.1918 this cost 0.7508604526519775
# At step  64 the train_score is  0.19816364 the validation score is  0.1956 this cost 0.7479381561279297
# At step  65 the train_score is  0.20165454 the validation score is  0.1982 this cost 0.7461104393005371
# At step  66 the train_score is  0.2052 the validation score is  0.201 this cost 0.7471888065338135
# At step  67 the train_score is  0.2082909 the validation score is  0.2052 this cost 0.7517247200012207
# At step  68 the train_score is  0.21176364 the validation score is  0.2084 this cost 0.7449476718902588
# At step  69 the train_score is  0.21523637 the validation score is  0.2124 this cost 0.7431268692016602
# At step  70 the train_score is  0.2187091 the validation score is  0.2148 this cost 0.7472641468048096
# At step  71 the train_score is  0.22194545 the validation score is  0.2182 this cost 0.7533044815063477
# At step  72 the train_score is  0.22518182 the validation score is  0.2218 this cost 0.751091718673706
# At step  73 the train_score is  0.2283091 the validation score is  0.2266 this cost 0.7515616416931152
# At step  74 the train_score is  0.23178183 the validation score is  0.2314 this cost 0.7451033592224121
# At step  75 the train_score is  0.23509091 the validation score is  0.2346 this cost 0.745943546295166
# At step  76 the train_score is  0.23841818 the validation score is  0.2388 this cost 0.7439570426940918
# At step  77 the train_score is  0.24167272 the validation score is  0.2422 this cost 0.7449874877929688
# At step  78 the train_score is  0.24523637 the validation score is  0.2446 this cost 0.7431466579437256
# At step  79 the train_score is  0.24881819 the validation score is  0.247 this cost 0.7520661354064941
# At step  80 the train_score is  0.25283638 the validation score is  0.2516 this cost 0.7447993755340576
# At step  81 the train_score is  0.25614545 the validation score is  0.2544 this cost 0.7504050731658936
# At step  82 the train_score is  0.2594 the validation score is  0.2572 this cost 0.7477405071258545
# At step  83 the train_score is  0.2630182 the validation score is  0.261 this cost 0.747044563293457
# At step  84 the train_score is  0.2669091 the validation score is  0.265 this cost 0.7500808238983154
# At step  85 the train_score is  0.27067274 the validation score is  0.2688 this cost 0.747081995010376
# At step  86 the train_score is  0.27454546 the validation score is  0.272 this cost 0.7496447563171387
# At step  87 the train_score is  0.27827272 the validation score is  0.2748 this cost 0.7491533756256104
# At step  88 the train_score is  0.28165454 the validation score is  0.279 this cost 0.7499489784240723
# At step  89 the train_score is  0.28525454 the validation score is  0.281 this cost 0.7409093379974365
# At step  90 the train_score is  0.28874546 the validation score is  0.2832 this cost 0.7501182556152344
# At step  91 the train_score is  0.29243636 the validation score is  0.2864 this cost 0.7511377334594727
# At step  92 the train_score is  0.29607272 the validation score is  0.2902 this cost 0.7448828220367432
# At step  93 the train_score is  0.2993091 the validation score is  0.2936 this cost 0.7472381591796875
# At step  94 the train_score is  0.30301818 the validation score is  0.2958 this cost 0.7456390857696533
# At step  95 the train_score is  0.30634546 the validation score is  0.2994 this cost 0.7507283687591553
# At step  96 the train_score is  0.3097091 the validation score is  0.3034 this cost 0.7501139640808105
# At step  97 the train_score is  0.31336364 the validation score is  0.308 this cost 0.7534682750701904
# At step  98 the train_score is  0.31641817 the validation score is  0.3116 this cost 0.7783515453338623
# At step  99 the train_score is  0.31989092 the validation score is  0.3152 this cost 0.7983849048614502
# At step  100 the train_score is  0.32352728 the validation score is  0.3184 this cost 0.7664227485656738
# At step  101 the train_score is  0.3267091 the validation score is  0.3216 this cost 0.7805900573730469
# At step  102 the train_score is  0.33056363 the validation score is  0.3248 this cost 0.7895312309265137
# At step  103 the train_score is  0.3339818 the validation score is  0.3272 this cost 0.7722251415252686
# At step  104 the train_score is  0.3377091 the validation score is  0.3308 this cost 0.7741317749023438
# At step  105 the train_score is  0.34101817 the validation score is  0.3328 this cost 0.7849538326263428
# At step  106 the train_score is  0.34423637 the validation score is  0.3368 this cost 0.7581732273101807
# At step  107 the train_score is  0.3472909 the validation score is  0.34 this cost 0.7391650676727295
# At step  108 the train_score is  0.35050908 the validation score is  0.3436 this cost 0.744617223739624
# At step  109 the train_score is  0.35356364 the validation score is  0.349 this cost 0.7461965084075928
# At step  110 the train_score is  0.35652727 the validation score is  0.3514 this cost 0.7427747249603271
# At step  111 the train_score is  0.35923636 the validation score is  0.3542 this cost 0.7823097705841064
# At step  112 the train_score is  0.36249092 the validation score is  0.3588 this cost 0.7439651489257812
# At step  113 the train_score is  0.3654 the validation score is  0.3626 this cost 0.74588942527771
# At step  114 the train_score is  0.36852726 the validation score is  0.366 this cost 0.7464635372161865
# At step  115 the train_score is  0.37165454 the validation score is  0.3696 this cost 0.7544825077056885
# At step  116 the train_score is  0.37467274 the validation score is  0.373 this cost 0.7450742721557617
# At step  117 the train_score is  0.37745455 the validation score is  0.3762 this cost 0.7428526878356934
# At step  118 the train_score is  0.3802 the validation score is  0.3784 this cost 0.7398948669433594
# At step  119 the train_score is  0.38265455 the validation score is  0.3812 this cost 0.7486867904663086
# At step  120 the train_score is  0.38590908 the validation score is  0.3842 this cost 0.7400150299072266
# At step  121 the train_score is  0.38856363 the validation score is  0.3868 this cost 0.7440042495727539
# At step  122 the train_score is  0.39134544 the validation score is  0.39 this cost 0.7408199310302734
# At step  123 the train_score is  0.39387274 the validation score is  0.392 this cost 0.7370560169219971
# At step  124 the train_score is  0.39645454 the validation score is  0.3946 this cost 0.7437334060668945
# At step  125 the train_score is  0.399 the validation score is  0.398 this cost 0.7404372692108154
# At step  126 the train_score is  0.40185454 the validation score is  0.3998 this cost 0.7401673793792725
# At step  127 the train_score is  0.40441817 the validation score is  0.403 this cost 0.7386202812194824
# At step  128 the train_score is  0.407 the validation score is  0.4054 this cost 0.7386646270751953
# At step  129 the train_score is  0.40945455 the validation score is  0.4078 this cost 0.7425825595855713
# At step  130 the train_score is  0.41192728 the validation score is  0.4108 this cost 0.7404966354370117
# At step  131 the train_score is  0.41438183 the validation score is  0.4142 this cost 0.7472548484802246
# At step  132 the train_score is  0.41656363 the validation score is  0.4158 this cost 0.753486156463623
# At step  133 the train_score is  0.41916364 the validation score is  0.4186 this cost 0.7478463649749756
# At step  134 the train_score is  0.42167273 the validation score is  0.421 this cost 0.7420504093170166
# At step  135 the train_score is  0.42412728 the validation score is  0.4248 this cost 0.7389829158782959
# At step  136 the train_score is  0.42676362 the validation score is  0.4276 this cost 0.7510123252868652
# At step  137 the train_score is  0.4291091 the validation score is  0.4306 this cost 0.7487015724182129
# At step  138 the train_score is  0.43138182 the validation score is  0.433 this cost 0.7489933967590332
# At step  139 the train_score is  0.43374544 the validation score is  0.4358 this cost 0.743452787399292
# At step  140 the train_score is  0.43605456 the validation score is  0.4384 this cost 0.7380106449127197
# At step  141 the train_score is  0.43821818 the validation score is  0.4408 this cost 0.740729808807373
# At step  142 the train_score is  0.44014546 the validation score is  0.4434 this cost 0.7356736660003662
# At step  143 the train_score is  0.44238183 the validation score is  0.4448 this cost 0.7374229431152344
# At step  144 the train_score is  0.44456363 the validation score is  0.447 this cost 0.7388622760772705
# At step  145 the train_score is  0.4465091 the validation score is  0.4492 this cost 0.7523186206817627
# At step  146 the train_score is  0.4483091 the validation score is  0.4522 this cost 0.7918479442596436
# At step  147 the train_score is  0.45032728 the validation score is  0.454 this cost 0.7719902992248535
# At step  148 the train_score is  0.45221817 the validation score is  0.4546 this cost 0.7550530433654785
# At step  149 the train_score is  0.45401818 the validation score is  0.4556 this cost 0.7345633506774902
# At step  150 the train_score is  0.45567274 the validation score is  0.4578 this cost 0.7356810569763184
# At step  151 the train_score is  0.4579273 the validation score is  0.4598 this cost 0.7364368438720703
# At step  152 the train_score is  0.45961818 the validation score is  0.4612 this cost 0.7349731922149658
# At step  153 the train_score is  0.46174544 the validation score is  0.4628 this cost 0.735745906829834
# At step  154 the train_score is  0.46383637 the validation score is  0.4652 this cost 0.7359316349029541
# At step  155 the train_score is  0.46572727 the validation score is  0.467 this cost 0.7349512577056885
# At step  156 the train_score is  0.46761817 the validation score is  0.4698 this cost 0.757188081741333
# At step  157 the train_score is  0.46934545 the validation score is  0.4716 this cost 0.774742841720581
# At step  158 the train_score is  0.47136363 the validation score is  0.4738 this cost 0.748772144317627
# At step  159 the train_score is  0.47276363 the validation score is  0.4764 this cost 0.7419257164001465
# At step  160 the train_score is  0.4744 the validation score is  0.4778 this cost 0.7313027381896973
# At step  161 the train_score is  0.4762182 the validation score is  0.4794 this cost 0.7506029605865479
# At step  162 the train_score is  0.47796363 the validation score is  0.4814 this cost 0.7393860816955566
# At step  163 the train_score is  0.47994545 the validation score is  0.4838 this cost 0.7484586238861084
# At step  164 the train_score is  0.48118183 the validation score is  0.4862 this cost 0.7496674060821533
# At step  165 the train_score is  0.4828909 the validation score is  0.4876 this cost 0.7423036098480225
# At step  166 the train_score is  0.48450908 the validation score is  0.4896 this cost 0.7501401901245117
# At step  167 the train_score is  0.48630908 the validation score is  0.4922 this cost 0.7369446754455566
# At step  168 the train_score is  0.48778182 the validation score is  0.4944 this cost 0.7375993728637695
# At step  169 the train_score is  0.4896909 the validation score is  0.4964 this cost 0.7372531890869141
# At step  170 the train_score is  0.4914909 the validation score is  0.4982 this cost 0.7405343055725098
# At step  171 the train_score is  0.49305454 the validation score is  0.4996 this cost 0.7403519153594971
# At step  172 the train_score is  0.49487272 the validation score is  0.5008 this cost 0.7455940246582031
# At step  173 the train_score is  0.49661818 the validation score is  0.5014 this cost 0.7383933067321777
# At step  174 the train_score is  0.4980727 the validation score is  0.5024 this cost 0.7381865978240967
# At step  175 the train_score is  0.49947274 the validation score is  0.504 this cost 0.7404601573944092
# At step  176 the train_score is  0.50112724 the validation score is  0.5068 this cost 0.743260383605957
# At step  177 the train_score is  0.50258183 the validation score is  0.5082 this cost 0.7437560558319092
# At step  178 the train_score is  0.5041818 the validation score is  0.5102 this cost 0.7428138256072998
# At step  179 the train_score is  0.5055636 the validation score is  0.5124 this cost 0.7409090995788574
# At step  180 the train_score is  0.50694543 the validation score is  0.5146 this cost 0.7585482597351074
# At step  181 the train_score is  0.50821817 the validation score is  0.5158 this cost 0.7456502914428711
# At step  182 the train_score is  0.5092546 the validation score is  0.5178 this cost 0.7465403079986572
# At step  183 the train_score is  0.511 the validation score is  0.52 this cost 0.7422122955322266
# At step  184 the train_score is  0.5123636 the validation score is  0.523 this cost 0.7423684597015381
# At step  185 the train_score is  0.51356363 the validation score is  0.525 this cost 0.7398087978363037
# At step  186 the train_score is  0.51478183 the validation score is  0.526 this cost 0.743037223815918
# At step  187 the train_score is  0.5160909 the validation score is  0.5278 this cost 0.7458891868591309
# At step  188 the train_score is  0.5175818 the validation score is  0.529 this cost 0.7449080944061279
# At step  189 the train_score is  0.5190909 the validation score is  0.5296 this cost 0.7409532070159912
# At step  190 the train_score is  0.52052724 the validation score is  0.5306 this cost 0.7326114177703857
# At step  191 the train_score is  0.5218727 the validation score is  0.5326 this cost 0.7458796501159668
# At step  192 the train_score is  0.52329093 the validation score is  0.5332 this cost 0.7444970607757568
# At step  193 the train_score is  0.5248182 the validation score is  0.5344 this cost 0.7412185668945312
# At step  194 the train_score is  0.5262909 the validation score is  0.5364 this cost 0.7486302852630615
# At step  195 the train_score is  0.52761817 the validation score is  0.5366 this cost 0.740187406539917
# At step  196 the train_score is  0.52901816 the validation score is  0.5378 this cost 0.7480080127716064
# At step  197 the train_score is  0.5302909 the validation score is  0.54 this cost 0.7476723194122314
# At step  198 the train_score is  0.5315091 the validation score is  0.5414 this cost 0.7383244037628174
# At step  199 the train_score is  0.53303635 the validation score is  0.5424 this cost 0.738492488861084
# At step  200 the train_score is  0.53456366 the validation score is  0.544 this cost 0.741469144821167
# At step  201 the train_score is  0.5357636 the validation score is  0.5452 this cost 0.7393748760223389
# At step  202 the train_score is  0.5372364 the validation score is  0.5466 this cost 0.738426685333252
# At step  203 the train_score is  0.5385091 the validation score is  0.5478 this cost 0.7398159503936768
# At step  204 the train_score is  0.53990906 the validation score is  0.5486 this cost 0.7447175979614258
# At step  205 the train_score is  0.54103637 the validation score is  0.55 this cost 0.7417192459106445
# At step  206 the train_score is  0.5422364 the validation score is  0.551 this cost 0.7420332431793213
# At step  207 the train_score is  0.5436 the validation score is  0.5524 this cost 0.7355241775512695
# At step  208 the train_score is  0.5446727 the validation score is  0.5534 this cost 0.7505254745483398
# At step  209 the train_score is  0.5457818 the validation score is  0.5552 this cost 0.7397494316101074
# At step  210 the train_score is  0.54716367 the validation score is  0.5556 this cost 0.7368574142456055
# At step  211 the train_score is  0.5486 the validation score is  0.5566 this cost 0.7481739521026611
# At step  212 the train_score is  0.54965454 the validation score is  0.5576 this cost 0.7444143295288086
# At step  213 the train_score is  0.5507454 the validation score is  0.5588 this cost 0.7409162521362305
# At step  214 the train_score is  0.5518182 the validation score is  0.5596 this cost 0.7396888732910156
# At step  215 the train_score is  0.5531091 the validation score is  0.5616 this cost 0.7537581920623779
# At step  216 the train_score is  0.5541818 the validation score is  0.5634 this cost 0.7492847442626953
# At step  217 the train_score is  0.5554182 the validation score is  0.564 this cost 0.766402006149292
# At step  218 the train_score is  0.5568 the validation score is  0.565 this cost 0.7772393226623535
# At step  219 the train_score is  0.55783635 the validation score is  0.5668 this cost 0.7827332019805908
# At step  220 the train_score is  0.5590909 the validation score is  0.5678 this cost 0.7668490409851074
# At step  221 the train_score is  0.56012726 the validation score is  0.568 this cost 0.7838907241821289
# At step  222 the train_score is  0.56112725 the validation score is  0.5696 this cost 0.772711992263794
# At step  223 the train_score is  0.5620546 the validation score is  0.571 this cost 0.7715511322021484
# At step  224 the train_score is  0.56325454 the validation score is  0.572 this cost 0.7447793483734131
# At step  225 the train_score is  0.5645091 the validation score is  0.5736 this cost 0.7481667995452881
# At step  226 the train_score is  0.5653818 the validation score is  0.574 this cost 0.7369065284729004
# At step  227 the train_score is  0.56665456 the validation score is  0.5752 this cost 0.7369859218597412
# At step  228 the train_score is  0.5676 the validation score is  0.576 this cost 0.7437946796417236
# At step  229 the train_score is  0.5685091 the validation score is  0.5776 this cost 0.746274471282959
# At step  230 the train_score is  0.5695818 the validation score is  0.5792 this cost 0.7514967918395996
# At step  231 the train_score is  0.5704909 the validation score is  0.5806 this cost 0.7805557250976562
# At step  232 the train_score is  0.5714909 the validation score is  0.5818 this cost 0.7751379013061523
# At step  233 the train_score is  0.57247275 the validation score is  0.583 this cost 0.740994930267334
# At step  234 the train_score is  0.57356364 the validation score is  0.5836 this cost 0.7369046211242676
# At step  235 the train_score is  0.57443637 the validation score is  0.5846 this cost 0.7492091655731201
# At step  236 the train_score is  0.5753818 the validation score is  0.5864 this cost 0.7438244819641113
# At step  237 the train_score is  0.5762 the validation score is  0.587 this cost 0.7473592758178711
# At step  238 the train_score is  0.5773091 the validation score is  0.589 this cost 0.7444398403167725
# At step  239 the train_score is  0.5783455 the validation score is  0.5892 this cost 0.7467315196990967
# At step  240 the train_score is  0.5791636 the validation score is  0.591 this cost 0.7368817329406738
# At step  241 the train_score is  0.5801455 the validation score is  0.592 this cost 0.744229793548584
# At step  242 the train_score is  0.58107275 the validation score is  0.593 this cost 0.7399370670318604
# At step  243 the train_score is  0.58205456 the validation score is  0.5934 this cost 0.7463855743408203
# At step  244 the train_score is  0.5831091 the validation score is  0.5944 this cost 0.7459168434143066
# At step  245 the train_score is  0.5838364 the validation score is  0.5954 this cost 0.7419524192810059
# At step  246 the train_score is  0.58467275 the validation score is  0.596 this cost 0.7467811107635498
# At step  247 the train_score is  0.5856182 the validation score is  0.597 this cost 0.7428710460662842
# At step  248 the train_score is  0.58647275 the validation score is  0.5984 this cost 0.7404923439025879
# At step  249 the train_score is  0.5872909 the validation score is  0.5992 this cost 0.7379982471466064
# At step  250 the train_score is  0.58814543 the validation score is  0.6012 this cost 0.7474164962768555
# At step  251 the train_score is  0.58903635 the validation score is  0.6024 this cost 0.7494692802429199
# At step  252 the train_score is  0.59001815 the validation score is  0.6032 this cost 0.7409906387329102
# At step  253 the train_score is  0.5910182 the validation score is  0.6046 this cost 0.7379107475280762
# At step  254 the train_score is  0.5918 the validation score is  0.6052 this cost 0.7466073036193848
# At step  255 the train_score is  0.5925818 the validation score is  0.606 this cost 0.7520837783813477
# At step  256 the train_score is  0.59343636 the validation score is  0.607 this cost 0.7448971271514893
# At step  257 the train_score is  0.59434545 the validation score is  0.608 this cost 0.741086483001709
# At step  258 the train_score is  0.5951091 the validation score is  0.6086 this cost 0.7446103096008301
# At step  259 the train_score is  0.59596366 the validation score is  0.6088 this cost 0.7471084594726562
# At step  260 the train_score is  0.5966909 the validation score is  0.6104 this cost 0.7438106536865234
# At step  261 the train_score is  0.5977273 the validation score is  0.6102 this cost 0.7448961734771729
# At step  262 the train_score is  0.5986909 the validation score is  0.6112 this cost 0.7756943702697754
# At step  263 the train_score is  0.5998 the validation score is  0.6126 this cost 0.787057638168335
# At step  264 the train_score is  0.6006727 the validation score is  0.6134 this cost 0.7724487781524658
# At step  265 the train_score is  0.60154545 the validation score is  0.6134 this cost 0.7938745021820068
# At step  266 the train_score is  0.6022364 the validation score is  0.6136 this cost 0.7769978046417236
# At step  267 the train_score is  0.60327274 the validation score is  0.6144 this cost 0.779747486114502
# At step  268 the train_score is  0.604 the validation score is  0.6156 this cost 0.7670102119445801
# At step  269 the train_score is  0.60472727 the validation score is  0.6158 this cost 0.7747242450714111
# At step  270 the train_score is  0.60538185 the validation score is  0.617 this cost 0.7645106315612793
# At step  271 the train_score is  0.60612726 the validation score is  0.6172 this cost 0.7528829574584961
# At step  272 the train_score is  0.60694546 the validation score is  0.618 this cost 0.7466297149658203
# At step  273 the train_score is  0.60752726 the validation score is  0.6186 this cost 0.7714629173278809
# At step  274 the train_score is  0.6082909 the validation score is  0.6198 this cost 0.7686023712158203
# At step  275 the train_score is  0.60907274 the validation score is  0.6204 this cost 0.7783908843994141
# At step  276 the train_score is  0.6097091 the validation score is  0.621 this cost 0.7739269733428955
# At step  277 the train_score is  0.61047274 the validation score is  0.6224 this cost 0.740957498550415
# At step  278 the train_score is  0.61121815 the validation score is  0.6226 this cost 0.7427318096160889
# At step  279 the train_score is  0.61201817 the validation score is  0.6236 this cost 0.782576322555542
# At step  280 the train_score is  0.6126364 the validation score is  0.624 this cost 0.7650866508483887
# At step  281 the train_score is  0.6133636 the validation score is  0.6242 this cost 0.7689483165740967
# At step  282 the train_score is  0.6141091 the validation score is  0.6248 this cost 0.7849175930023193
# At step  283 the train_score is  0.6150727 the validation score is  0.6258 this cost 0.7578380107879639
# At step  284 the train_score is  0.6156727 the validation score is  0.6266 this cost 0.7409732341766357
# At step  285 the train_score is  0.61625457 the validation score is  0.627 this cost 0.7316293716430664
# At step  286 the train_score is  0.6170545 the validation score is  0.6276 this cost 0.7473795413970947
# At step  287 the train_score is  0.6178 the validation score is  0.6282 this cost 0.7493443489074707
# At step  288 the train_score is  0.61856365 the validation score is  0.629 this cost 0.7363784313201904
# At step  289 the train_score is  0.6194182 the validation score is  0.6294 this cost 0.7352864742279053
# At step  290 the train_score is  0.62014544 the validation score is  0.6298 this cost 0.7532923221588135
# At step  291 the train_score is  0.62076366 the validation score is  0.6308 this cost 0.7728095054626465
# At step  292 the train_score is  0.62143636 the validation score is  0.6318 this cost 0.741100549697876
# At step  293 the train_score is  0.6222 the validation score is  0.6328 this cost 0.7396059036254883
# At step  294 the train_score is  0.6230364 the validation score is  0.6338 this cost 0.7468564510345459
# At step  295 the train_score is  0.6237818 the validation score is  0.6348 this cost 0.7434585094451904
# At step  296 the train_score is  0.62445456 the validation score is  0.6352 this cost 0.7423732280731201
# At step  297 the train_score is  0.6252364 the validation score is  0.636 this cost 0.7375907897949219
# At step  298 the train_score is  0.62592727 the validation score is  0.6366 this cost 0.7392673492431641
# At step  299 the train_score is  0.6265454 the validation score is  0.6372 this cost 0.7382769584655762
# At step  300 the train_score is  0.6272727 the validation score is  0.6384 this cost 0.7418677806854248
# At step  301 the train_score is  0.62798184 the validation score is  0.639 this cost 0.7418367862701416
# At step  302 the train_score is  0.6287091 the validation score is  0.6402 this cost 0.739403486251831
# At step  303 the train_score is  0.62954545 the validation score is  0.6414 this cost 0.7436518669128418
# At step  304 the train_score is  0.6300909 the validation score is  0.642 this cost 0.7401785850524902
# At step  305 the train_score is  0.63069093 the validation score is  0.6422 this cost 0.7382664680480957
# At step  306 the train_score is  0.63136363 the validation score is  0.6426 this cost 0.7426536083221436
# At step  307 the train_score is  0.632 the validation score is  0.6432 this cost 0.7475814819335938
# At step  308 the train_score is  0.6326182 the validation score is  0.6444 this cost 0.7428011894226074
# At step  309 the train_score is  0.63307273 the validation score is  0.6446 this cost 0.7467701435089111
# At step  310 the train_score is  0.6336909 the validation score is  0.6448 this cost 0.7459843158721924
# At step  311 the train_score is  0.6343273 the validation score is  0.6448 this cost 0.74546217918396
# At step  312 the train_score is  0.63510907 the validation score is  0.645 this cost 0.7417311668395996
# At step  313 the train_score is  0.63574547 the validation score is  0.6456 this cost 0.7475309371948242
# At step  314 the train_score is  0.6364 the validation score is  0.6466 this cost 0.7430825233459473
# At step  315 the train_score is  0.6368909 the validation score is  0.6468 this cost 0.7472329139709473
# At step  316 the train_score is  0.6374182 the validation score is  0.6478 this cost 0.7416565418243408
# At step  317 the train_score is  0.6380727 the validation score is  0.6488 this cost 0.7373168468475342
# At step  318 the train_score is  0.6386182 the validation score is  0.649 this cost 0.7404747009277344
# At step  319 the train_score is  0.6394182 the validation score is  0.65 this cost 0.7397518157958984
# At step  320 the train_score is  0.6402182 the validation score is  0.6512 this cost 0.7443764209747314
# At step  321 the train_score is  0.6410364 the validation score is  0.6522 this cost 0.7418503761291504
# At step  322 the train_score is  0.64158183 the validation score is  0.6524 this cost 0.7410197257995605
# At step  323 the train_score is  0.6420182 the validation score is  0.6528 this cost 0.7808465957641602
# At step  324 the train_score is  0.6426 the validation score is  0.6532 this cost 0.7910759449005127
# At step  325 the train_score is  0.6431636 the validation score is  0.654 this cost 0.7717370986938477
# At step  326 the train_score is  0.6438364 the validation score is  0.6546 this cost 0.777869462966919
# At step  327 the train_score is  0.6444727 the validation score is  0.6552 this cost 0.793036699295044
# At step  328 the train_score is  0.64494544 the validation score is  0.656 this cost 0.7934441566467285
# At step  329 the train_score is  0.64565456 the validation score is  0.6566 this cost 0.8031904697418213
# At step  330 the train_score is  0.6462727 the validation score is  0.6568 this cost 0.8057403564453125
# At step  331 the train_score is  0.64681816 the validation score is  0.6576 this cost 0.7577719688415527
# At step  332 the train_score is  0.6474 the validation score is  0.6574 this cost 0.7371690273284912
# At step  333 the train_score is  0.6479091 the validation score is  0.6576 this cost 0.751394510269165
# At step  334 the train_score is  0.6483818 the validation score is  0.658 this cost 0.7409408092498779
# At step  335 the train_score is  0.64901817 the validation score is  0.6582 this cost 0.7519831657409668
# At step  336 the train_score is  0.64945453 the validation score is  0.6586 this cost 0.7494101524353027
# At step  337 the train_score is  0.6501455 the validation score is  0.6588 this cost 0.7517683506011963
# At step  338 the train_score is  0.65090907 the validation score is  0.6594 this cost 0.7513535022735596
# At step  339 the train_score is  0.6513091 the validation score is  0.6596 this cost 0.7494533061981201
# At step  340 the train_score is  0.6519273 the validation score is  0.6596 this cost 0.778289794921875
# At step  341 the train_score is  0.65247273 the validation score is  0.6598 this cost 0.761890172958374
# At step  342 the train_score is  0.6528909 the validation score is  0.6602 this cost 0.7500913143157959
# At step  343 the train_score is  0.6534909 the validation score is  0.661 this cost 0.7887969017028809
# At step  344 the train_score is  0.6539818 the validation score is  0.6614 this cost 0.7521076202392578
# At step  345 the train_score is  0.6544909 the validation score is  0.6618 this cost 0.753298282623291
# At step  346 the train_score is  0.6549636 the validation score is  0.6622 this cost 0.7470922470092773
# At step  347 the train_score is  0.65549093 the validation score is  0.6622 this cost 0.7545208930969238
# At step  348 the train_score is  0.6561091 the validation score is  0.6626 this cost 0.7662017345428467
# At step  349 the train_score is  0.6565273 the validation score is  0.6634 this cost 0.7895731925964355
# At step  350 the train_score is  0.65712726 the validation score is  0.6638 this cost 0.7687485218048096
# At step  351 the train_score is  0.65761817 the validation score is  0.664 this cost 0.773043155670166
# At step  352 the train_score is  0.6582364 the validation score is  0.6648 this cost 0.7846601009368896
# At step  353 the train_score is  0.659 the validation score is  0.6652 this cost 0.7825760841369629
# At step  354 the train_score is  0.6595455 the validation score is  0.666 this cost 0.7515158653259277
# At step  355 the train_score is  0.65998185 the validation score is  0.6664 this cost 0.7500030994415283
# At step  356 the train_score is  0.6603818 the validation score is  0.6674 this cost 0.760181188583374
# At step  357 the train_score is  0.66089094 the validation score is  0.6678 this cost 0.7509503364562988
# At step  358 the train_score is  0.6613273 the validation score is  0.6678 this cost 0.748445987701416
# At step  359 the train_score is  0.6618182 the validation score is  0.6688 this cost 0.7422962188720703
# At step  360 the train_score is  0.6624727 the validation score is  0.6692 this cost 0.7349984645843506
# At step  361 the train_score is  0.663 the validation score is  0.6694 this cost 0.7474348545074463
# At step  362 the train_score is  0.6634 the validation score is  0.67 this cost 0.774416446685791
# At step  363 the train_score is  0.66392726 the validation score is  0.67 this cost 0.7804973125457764
# At step  364 the train_score is  0.66432726 the validation score is  0.6704 this cost 0.7489540576934814
# At step  365 the train_score is  0.6648545 the validation score is  0.6714 this cost 0.7570617198944092
# At step  366 the train_score is  0.66532725 the validation score is  0.6714 this cost 0.7702162265777588
# At step  367 the train_score is  0.6659091 the validation score is  0.672 this cost 0.7470118999481201
# At step  368 the train_score is  0.66629094 the validation score is  0.6722 this cost 0.7427198886871338
# At step  369 the train_score is  0.66663635 the validation score is  0.6734 this cost 0.7488036155700684
# At step  370 the train_score is  0.6672 the validation score is  0.674 this cost 0.7405397891998291
# At step  371 the train_score is  0.6675636 the validation score is  0.6748 this cost 0.740556001663208
# At step  372 the train_score is  0.6681273 the validation score is  0.6758 this cost 0.7373054027557373
# At step  373 the train_score is  0.6686 the validation score is  0.676 this cost 0.7365992069244385
# At step  374 the train_score is  0.6691273 the validation score is  0.6768 this cost 0.739288330078125
# At step  375 the train_score is  0.6696727 the validation score is  0.6774 this cost 0.7438807487487793
# At step  376 the train_score is  0.6702 the validation score is  0.6778 this cost 0.7395470142364502
# At step  377 the train_score is  0.6706909 the validation score is  0.6778 this cost 0.7393765449523926
# At step  378 the train_score is  0.6711818 the validation score is  0.678 this cost 0.7385268211364746
# At step  379 the train_score is  0.67163634 the validation score is  0.678 this cost 0.7342236042022705
# At step  380 the train_score is  0.6720727 the validation score is  0.679 this cost 0.7418944835662842
# At step  381 the train_score is  0.6725818 the validation score is  0.6794 this cost 0.7548966407775879
# At step  382 the train_score is  0.67318183 the validation score is  0.6796 this cost 0.7398931980133057
# At step  383 the train_score is  0.67356366 the validation score is  0.6802 this cost 0.759772539138794
# At step  384 the train_score is  0.6738909 the validation score is  0.6802 this cost 0.7412302494049072
# At step  385 the train_score is  0.67434543 the validation score is  0.6806 this cost 0.7574489116668701
# At step  386 the train_score is  0.67487276 the validation score is  0.6808 this cost 0.7514426708221436
# At step  387 the train_score is  0.67530906 the validation score is  0.6814 this cost 0.7445220947265625
# At step  388 the train_score is  0.6759091 the validation score is  0.6818 this cost 0.743837833404541
# At step  389 the train_score is  0.67636365 the validation score is  0.6824 this cost 0.7462751865386963
# At step  390 the train_score is  0.6768364 the validation score is  0.6826 this cost 0.7396414279937744
# At step  391 the train_score is  0.6774909 the validation score is  0.6832 this cost 0.7487912178039551
# At step  392 the train_score is  0.67774546 the validation score is  0.6834 this cost 0.7549984455108643
# At step  393 the train_score is  0.6781818 the validation score is  0.684 this cost 0.738170862197876
# At step  394 the train_score is  0.6786364 the validation score is  0.6848 this cost 0.7352840900421143
# At step  395 the train_score is  0.6789273 the validation score is  0.6852 this cost 0.735588550567627
# At step  396 the train_score is  0.6794364 the validation score is  0.6854 this cost 0.737058162689209
# At step  397 the train_score is  0.6799091 the validation score is  0.686 this cost 0.7361948490142822
# At step  398 the train_score is  0.6803273 the validation score is  0.686 this cost 0.7340278625488281
# At step  399 the train_score is  0.6806909 the validation score is  0.6864 this cost 0.736351728439331
# At step  400 the train_score is  0.6810909 the validation score is  0.6866 this cost 0.7332427501678467
# At step  401 the train_score is  0.68145454 the validation score is  0.687 this cost 0.7350864410400391
# At step  402 the train_score is  0.6818182 the validation score is  0.6878 this cost 0.7368772029876709
# At step  403 the train_score is  0.68250906 the validation score is  0.6882 this cost 0.7348673343658447
# At step  404 the train_score is  0.6826909 the validation score is  0.6884 this cost 0.7488312721252441
# At step  405 the train_score is  0.6832182 the validation score is  0.6888 this cost 0.7451128959655762
# At step  406 the train_score is  0.6836182 the validation score is  0.6894 this cost 0.7706315517425537
# At step  407 the train_score is  0.6840182 the validation score is  0.6898 this cost 0.7697708606719971
# At step  408 the train_score is  0.68438184 the validation score is  0.69 this cost 0.7458634376525879
# At step  409 the train_score is  0.6847091 the validation score is  0.69 this cost 0.7371852397918701
# At step  410 the train_score is  0.6851818 the validation score is  0.6906 this cost 0.7530839443206787
# At step  411 the train_score is  0.68576366 the validation score is  0.6908 this cost 0.740185022354126
# At step  412 the train_score is  0.6864182 the validation score is  0.6912 this cost 0.752408504486084
# At step  413 the train_score is  0.6868727 the validation score is  0.6918 this cost 0.7306585311889648
# At step  414 the train_score is  0.6872727 the validation score is  0.6932 this cost 0.7430450916290283
# At step  415 the train_score is  0.68781817 the validation score is  0.6936 this cost 0.7375016212463379
# At step  416 the train_score is  0.6882909 the validation score is  0.694 this cost 0.7416586875915527
# At step  417 the train_score is  0.68863636 the validation score is  0.6946 this cost 0.7378902435302734
# At step  418 the train_score is  0.6892 the validation score is  0.6948 this cost 0.7495200634002686
# At step  419 the train_score is  0.6896727 the validation score is  0.6952 this cost 0.7606658935546875
# At step  420 the train_score is  0.6900182 the validation score is  0.6954 this cost 0.7436373233795166
# At step  421 the train_score is  0.69067276 the validation score is  0.6958 this cost 0.7402985095977783
# At step  422 the train_score is  0.6909091 the validation score is  0.6958 this cost 0.753889799118042
# At step  423 the train_score is  0.6914545 the validation score is  0.6962 this cost 0.7560081481933594
# At step  424 the train_score is  0.6918727 the validation score is  0.6966 this cost 0.7415480613708496
# At step  425 the train_score is  0.69232726 the validation score is  0.6974 this cost 0.7408561706542969
# At step  426 the train_score is  0.69281816 the validation score is  0.698 this cost 0.7534866333007812
# At step  427 the train_score is  0.69330907 the validation score is  0.6982 this cost 0.7727439403533936
# At step  428 the train_score is  0.6936727 the validation score is  0.699 this cost 0.7598588466644287
# At step  429 the train_score is  0.694 the validation score is  0.6992 this cost 0.7728445529937744
# At step  430 the train_score is  0.69438183 the validation score is  0.6996 this cost 0.761406421661377
# At step  431 the train_score is  0.69476366 the validation score is  0.7 this cost 0.7401115894317627
# At step  432 the train_score is  0.6951454 the validation score is  0.7004 this cost 0.7426483631134033
# At step  433 the train_score is  0.6955818 the validation score is  0.7004 this cost 0.7656083106994629
# At step  434 the train_score is  0.6958727 the validation score is  0.7004 this cost 0.7529280185699463
# At step  435 the train_score is  0.69641817 the validation score is  0.7004 this cost 0.7923181056976318
# At step  436 the train_score is  0.69683635 the validation score is  0.7008 this cost 0.7611536979675293
# At step  437 the train_score is  0.6973091 the validation score is  0.7016 this cost 0.7550539970397949
# At step  438 the train_score is  0.6976727 the validation score is  0.7024 this cost 0.7560837268829346
# At step  439 the train_score is  0.6980364 the validation score is  0.7026 this cost 0.7477908134460449
# At step  440 the train_score is  0.6982545 the validation score is  0.703 this cost 0.7424447536468506
# At step  441 the train_score is  0.6986182 the validation score is  0.7034 this cost 0.7534983158111572
# At step  442 the train_score is  0.6988909 the validation score is  0.7046 this cost 0.773510217666626
# At step  443 the train_score is  0.6993091 the validation score is  0.7048 this cost 0.7515869140625
# At step  444 the train_score is  0.69978184 the validation score is  0.7054 this cost 0.7407169342041016
# At step  445 the train_score is  0.7002364 the validation score is  0.7062 this cost 0.7551336288452148
# At step  446 the train_score is  0.70083636 the validation score is  0.707 this cost 0.7587845325469971
# At step  447 the train_score is  0.70123637 the validation score is  0.7076 this cost 0.7400472164154053
# At step  448 the train_score is  0.7016364 the validation score is  0.7084 this cost 0.7332777976989746
# At step  449 the train_score is  0.7020182 the validation score is  0.7094 this cost 0.745919942855835
# At step  450 the train_score is  0.70232725 the validation score is  0.7098 this cost 0.7355756759643555
# At step  451 the train_score is  0.70265454 the validation score is  0.7102 this cost 0.7349963188171387
# At step  452 the train_score is  0.703 the validation score is  0.7102 this cost 0.7361528873443604
# At step  453 the train_score is  0.70338184 the validation score is  0.7102 this cost 0.7359793186187744
# At step  454 the train_score is  0.7037454 the validation score is  0.7106 this cost 0.7395124435424805
# At step  455 the train_score is  0.7041091 the validation score is  0.7108 this cost 0.7342500686645508
# At step  456 the train_score is  0.7046 the validation score is  0.7114 this cost 0.7325201034545898
# At step  457 the train_score is  0.7049818 the validation score is  0.7118 this cost 0.7330811023712158
# At step  458 the train_score is  0.7052909 the validation score is  0.7122 this cost 0.7349772453308105
# At step  459 the train_score is  0.7056364 the validation score is  0.7124 this cost 0.735771894454956
# At step  460 the train_score is  0.7058909 the validation score is  0.7128 this cost 0.7372734546661377
# At step  461 the train_score is  0.70623636 the validation score is  0.7136 this cost 0.7339286804199219
# At step  462 the train_score is  0.70649093 the validation score is  0.7142 this cost 0.7392451763153076
# ...
# At step  1848 the train_score is  0.8585455 the validation score is  0.867 this cost 0.7376422882080078
# At step  1849 the train_score is  0.85856366 the validation score is  0.8674 this cost 0.739041805267334
# At step  1850 the train_score is  0.8586364 the validation score is  0.8674 this cost 0.738640546798706
# At step  1851 the train_score is  0.85865456 the validation score is  0.8674 this cost 0.7371270656585693
# At step  1852 the train_score is  0.8587273 the validation score is  0.8674 this cost 0.7377655506134033
# At step  1853 the train_score is  0.85874546 the validation score is  0.8672 this cost 0.7373793125152588
# At step  1854 the train_score is  0.85876364 the validation score is  0.8672 this cost 0.7374653816223145
# At step  1855 the train_score is  0.8588 the validation score is  0.8672 this cost 0.7411644458770752
# At step  1856 the train_score is  0.8588182 the validation score is  0.8672 this cost 0.735015869140625
# At step  1857 the train_score is  0.8589091 the validation score is  0.8672 this cost 0.7467293739318848
# At step  1858 the train_score is  0.8588909 the validation score is  0.8674 this cost 0.7374968528747559
# At step  1859 the train_score is  0.8588909 the validation score is  0.8676 this cost 0.7431855201721191
# At step  1860 the train_score is  0.8588727 the validation score is  0.8676 this cost 0.7412757873535156
# At step  1861 the train_score is  0.85885453 the validation score is  0.8678 this cost 0.7395651340484619
# At step  1862 the train_score is  0.8589091 the validation score is  0.8676 this cost 0.7482297420501709
# At step  1863 the train_score is  0.8589454 the validation score is  0.8678 this cost 0.736764669418335
# At step  1864 the train_score is  0.859 the validation score is  0.8678 this cost 0.7382776737213135
# At step  1865 the train_score is  0.8590182 the validation score is  0.8678 this cost 0.7387979030609131
# At step  1866 the train_score is  0.85905457 the validation score is  0.8678 this cost 0.7387435436248779
# At step  1867 the train_score is  0.85907274 the validation score is  0.8678 this cost 0.7467308044433594
# At step  1868 the train_score is  0.8590909 the validation score is  0.8678 this cost 0.7396466732025146
# At step  1869 the train_score is  0.8591273 the validation score is  0.8678 this cost 0.7406508922576904
# At step  1870 the train_score is  0.85914546 the validation score is  0.8678 this cost 0.7367293834686279
# At step  1871 the train_score is  0.8591818 the validation score is  0.8678 this cost 0.7283380031585693
# At step  1872 the train_score is  0.85923636 the validation score is  0.8682 this cost 0.7566704750061035
# At step  1873 the train_score is  0.85925454 the validation score is  0.8682 this cost 0.7380421161651611
# At step  1874 the train_score is  0.8592909 the validation score is  0.8682 this cost 0.7398853302001953
# At step  1875 the train_score is  0.8593818 the validation score is  0.8682 this cost 0.7455432415008545
# At step  1876 the train_score is  0.85941815 the validation score is  0.8682 this cost 0.7394547462463379
# At step  1877 the train_score is  0.8594546 the validation score is  0.8682 this cost 0.7370870113372803
# At step  1878 the train_score is  0.85947275 the validation score is  0.8682 this cost 0.7377421855926514
# At step  1879 the train_score is  0.8595091 the validation score is  0.8682 this cost 0.7375876903533936
# At step  1880 the train_score is  0.85956365 the validation score is  0.8684 this cost 0.7400627136230469
# At step  1881 the train_score is  0.8596 the validation score is  0.8686 this cost 0.739234209060669
# At step  1882 the train_score is  0.85963637 the validation score is  0.8686 this cost 0.7410087585449219
# At step  1883 the train_score is  0.8596909 the validation score is  0.8686 this cost 0.7363567352294922
# At step  1884 the train_score is  0.8596909 the validation score is  0.8688 this cost 0.7362890243530273
# At step  1885 the train_score is  0.8597091 the validation score is  0.8688 this cost 0.7374582290649414
# At step  1886 the train_score is  0.85974544 the validation score is  0.8686 this cost 0.7395257949829102
# At step  1887 the train_score is  0.8597818 the validation score is  0.8686 this cost 0.7419147491455078
# At step  1888 the train_score is  0.85981816 the validation score is  0.8686 this cost 0.7380056381225586
# At step  1889 the train_score is  0.85981816 the validation score is  0.8688 this cost 0.7379024028778076
# At step  1890 the train_score is  0.85981816 the validation score is  0.8688 this cost 0.7387995719909668
# At step  1891 the train_score is  0.85981816 the validation score is  0.869 this cost 0.7381904125213623
# At step  1892 the train_score is  0.85989094 the validation score is  0.869 this cost 0.7365734577178955
# At step  1893 the train_score is  0.86 the validation score is  0.869 this cost 0.736513614654541
# At step  1894 the train_score is  0.85998183 the validation score is  0.869 this cost 0.7395668029785156
# At step  1895 the train_score is  0.85998183 the validation score is  0.869 this cost 0.7375814914703369
# At step  1896 the train_score is  0.86005455 the validation score is  0.8692 this cost 0.7377109527587891
# At step  1897 the train_score is  0.8601273 the validation score is  0.8694 this cost 0.7437303066253662
# At step  1898 the train_score is  0.8601636 the validation score is  0.8694 this cost 0.7383296489715576
# At step  1899 the train_score is  0.8602 the validation score is  0.8694 this cost 0.7375214099884033
# At step  1900 the train_score is  0.8602 the validation score is  0.8694 this cost 0.7466650009155273
# At step  1901 the train_score is  0.8602 the validation score is  0.8694 this cost 0.738961935043335
# At step  1902 the train_score is  0.8602545 the validation score is  0.8694 this cost 0.7362074851989746
# At step  1903 the train_score is  0.8602545 the validation score is  0.8694 this cost 0.7371740341186523
# At step  1904 the train_score is  0.8602909 the validation score is  0.8694 this cost 0.7357692718505859
# At step  1905 the train_score is  0.8603455 the validation score is  0.8694 this cost 0.737030029296875
# At step  1906 the train_score is  0.86038184 the validation score is  0.8694 this cost 0.7370295524597168
# At step  1907 the train_score is  0.8604 the validation score is  0.8694 this cost 0.7374169826507568
# At step  1908 the train_score is  0.8604364 the validation score is  0.8694 this cost 0.738818883895874
# At step  1909 the train_score is  0.86045456 the validation score is  0.8696 this cost 0.7368252277374268
# At step  1910 the train_score is  0.8604909 the validation score is  0.8696 this cost 0.7360332012176514
# At step  1911 the train_score is  0.8604909 the validation score is  0.8696 this cost 0.7401385307312012
# At step  1912 the train_score is  0.8605091 the validation score is  0.8698 this cost 0.7378003597259521
# At step  1913 the train_score is  0.8605273 the validation score is  0.8698 this cost 0.7381529808044434
# At step  1914 the train_score is  0.86056364 the validation score is  0.87 this cost 0.7364997863769531
# At step  1915 the train_score is  0.8606 the validation score is  0.87 this cost 0.7375366687774658
# At step  1916 the train_score is  0.8606182 the validation score is  0.87 this cost 0.7381324768066406
# At step  1917 the train_score is  0.86065453 the validation score is  0.87 this cost 0.7387077808380127
# At step  1918 the train_score is  0.8606909 the validation score is  0.87 this cost 0.7377429008483887
# At step  1919 the train_score is  0.8606909 the validation score is  0.8702 this cost 0.7378416061401367
# At step  1920 the train_score is  0.8606909 the validation score is  0.8702 this cost 0.7367594242095947
# At step  1921 the train_score is  0.8606909 the validation score is  0.8702 this cost 0.7364976406097412
# At step  1922 the train_score is  0.86074543 the validation score is  0.8702 this cost 0.7444052696228027
# At step  1923 the train_score is  0.8608182 the validation score is  0.87 this cost 0.7386596202850342
# At step  1924 the train_score is  0.86085457 the validation score is  0.87 this cost 0.7395946979522705
# At step  1925 the train_score is  0.8608909 the validation score is  0.8702 this cost 0.7378334999084473
# At step  1926 the train_score is  0.8608909 the validation score is  0.8702 this cost 0.7370467185974121
# At step  1927 the train_score is  0.8609273 the validation score is  0.8702 this cost 0.7377567291259766
# At step  1928 the train_score is  0.861 the validation score is  0.8704 this cost 0.742633581161499
# At step  1929 the train_score is  0.86103636 the validation score is  0.8704 this cost 0.7406890392303467
# At step  1930 the train_score is  0.8610727 the validation score is  0.8704 this cost 0.7386102676391602
# At step  1931 the train_score is  0.8611091 the validation score is  0.8704 this cost 0.7382216453552246
# At step  1932 the train_score is  0.8611636 the validation score is  0.8704 this cost 0.7367095947265625
# At step  1933 the train_score is  0.8612 the validation score is  0.8704 this cost 0.7370553016662598
# At step  1934 the train_score is  0.86127275 the validation score is  0.8704 this cost 0.7413372993469238
# At step  1935 the train_score is  0.86127275 the validation score is  0.8704 this cost 0.7370049953460693
# At step  1936 the train_score is  0.86129093 the validation score is  0.8704 this cost 0.73775315284729
# At step  1937 the train_score is  0.86129093 the validation score is  0.8704 this cost 0.7401020526885986
# At step  1938 the train_score is  0.86134547 the validation score is  0.8704 this cost 0.7398653030395508
# At step  1939 the train_score is  0.8614 the validation score is  0.8704 this cost 0.7369771003723145
# At step  1940 the train_score is  0.8614182 the validation score is  0.8704 this cost 0.7399511337280273
# At step  1941 the train_score is  0.86143637 the validation score is  0.8704 this cost 0.7389764785766602
# At step  1942 the train_score is  0.86145455 the validation score is  0.8704 this cost 0.7415122985839844
# At step  1943 the train_score is  0.8614727 the validation score is  0.8704 this cost 0.7413928508758545
# At step  1944 the train_score is  0.8615091 the validation score is  0.8704 this cost 0.7432730197906494
# At step  1945 the train_score is  0.8615091 the validation score is  0.8704 this cost 0.7429084777832031
# At step  1946 the train_score is  0.86152726 the validation score is  0.8704 this cost 0.75095534324646
# At step  1947 the train_score is  0.86154544 the validation score is  0.8704 this cost 0.7394576072692871
# At step  1948 the train_score is  0.8615818 the validation score is  0.8706 this cost 0.739210844039917
# At step  1949 the train_score is  0.86161816 the validation score is  0.8706 this cost 0.7373383045196533
# At step  1950 the train_score is  0.8616727 the validation score is  0.8706 this cost 0.745438814163208
# At step  1951 the train_score is  0.8617091 the validation score is  0.8706 this cost 0.736067533493042
# At step  1952 the train_score is  0.8617273 the validation score is  0.8708 this cost 0.738208532333374
# At step  1953 the train_score is  0.8617273 the validation score is  0.8708 this cost 0.7364063262939453
# At step  1954 the train_score is  0.8618 the validation score is  0.8708 this cost 0.7362432479858398
# At step  1955 the train_score is  0.8618182 the validation score is  0.8708 this cost 0.7376048564910889
# At step  1956 the train_score is  0.86185455 the validation score is  0.8708 this cost 0.7408156394958496
# At step  1957 the train_score is  0.86187273 the validation score is  0.8708 this cost 0.7393865585327148
# At step  1958 the train_score is  0.8619091 the validation score is  0.8708 this cost 0.7432513236999512
# At step  1959 the train_score is  0.86194545 the validation score is  0.8708 this cost 0.7391393184661865
# At step  1960 the train_score is  0.862 the validation score is  0.8708 this cost 0.7389435768127441
# At step  1961 the train_score is  0.862 the validation score is  0.8708 this cost 0.7398300170898438
# At step  1962 the train_score is  0.86201817 the validation score is  0.8708 this cost 0.7371184825897217
# At step  1963 the train_score is  0.8620545 the validation score is  0.8708 this cost 0.7408628463745117
# At step  1964 the train_score is  0.8620727 the validation score is  0.871 this cost 0.7399656772613525
# At step  1965 the train_score is  0.8621455 the validation score is  0.871 this cost 0.73834228515625
# At step  1966 the train_score is  0.86218184 the validation score is  0.871 this cost 0.7391684055328369
# At step  1967 the train_score is  0.86218184 the validation score is  0.871 this cost 0.7392792701721191
# At step  1968 the train_score is  0.8622364 the validation score is  0.871 this cost 0.7374827861785889
# At step  1969 the train_score is  0.8623091 the validation score is  0.871 this cost 0.7377934455871582
# At step  1970 the train_score is  0.8623818 the validation score is  0.871 this cost 0.7367246150970459
# At step  1971 the train_score is  0.8623818 the validation score is  0.871 this cost 0.7327539920806885
# At step  1972 the train_score is  0.8624182 the validation score is  0.871 this cost 0.744945764541626
# At step  1973 the train_score is  0.86245453 the validation score is  0.871 this cost 0.741957426071167
# At step  1974 the train_score is  0.86252725 the validation score is  0.871 this cost 0.7406868934631348
# At step  1975 the train_score is  0.8625636 the validation score is  0.871 this cost 0.7378814220428467
# At step  1976 the train_score is  0.8626182 the validation score is  0.871 this cost 0.7393355369567871
# At step  1977 the train_score is  0.86265457 the validation score is  0.871 this cost 0.7397675514221191
# At step  1978 the train_score is  0.86265457 the validation score is  0.871 this cost 0.7450075149536133
# At step  1979 the train_score is  0.86265457 the validation score is  0.871 this cost 0.741957426071167
# At step  1980 the train_score is  0.86267275 the validation score is  0.8712 this cost 0.7378787994384766
# At step  1981 the train_score is  0.86274546 the validation score is  0.8712 this cost 0.73661208152771
# At step  1982 the train_score is  0.8627273 the validation score is  0.8712 this cost 0.7394866943359375
# At step  1983 the train_score is  0.86276364 the validation score is  0.8712 this cost 0.7376530170440674
# At step  1984 the train_score is  0.86283636 the validation score is  0.8712 this cost 0.7426180839538574
# At step  1985 the train_score is  0.8628727 the validation score is  0.8712 this cost 0.7436506748199463
# At step  1986 the train_score is  0.8628727 the validation score is  0.8714 this cost 0.7381937503814697
# At step  1987 the train_score is  0.8628909 the validation score is  0.8714 this cost 0.7392337322235107
# At step  1988 the train_score is  0.8628909 the validation score is  0.8714 this cost 0.745734453201294
# At step  1989 the train_score is  0.8629091 the validation score is  0.8714 this cost 0.7378320693969727
# At step  1990 the train_score is  0.86292726 the validation score is  0.8714 this cost 0.7366254329681396
# At step  1991 the train_score is  0.86294544 the validation score is  0.8714 this cost 0.7405819892883301
# At step  1992 the train_score is  0.86294544 the validation score is  0.8714 this cost 0.7384095191955566
# At step  1993 the train_score is  0.86294544 the validation score is  0.8714 this cost 0.7388534545898438
# At step  1994 the train_score is  0.86294544 the validation score is  0.8714 this cost 0.7406535148620605
# At step  1995 the train_score is  0.86294544 the validation score is  0.8714 this cost 0.7410883903503418
# At step  1996 the train_score is  0.8629636 the validation score is  0.8714 this cost 0.7451434135437012
# At step  1997 the train_score is  0.8629636 the validation score is  0.8714 this cost 0.7380523681640625
# At step  1998 the train_score is  0.8629818 the validation score is  0.8714 this cost 0.7371046543121338
# At step  1999 the train_score is  0.863 the validation score is  0.8714 this cost 0.7372384071350098
# Run 2000 steps total process time is 1484.6108751296997
# the test set accuracy is 0.865

# %%
y_train.shape
# Out:
# (55000,)

# %%
from tensorflow_graph_in_jupyter import show_graph
show_graph(tf.get_default_graph())
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/polymer/0.3.3/platform.js&quot;></script>
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.3745401188473625&quot;).pbtxt = 'node {\n  name: &quot;X&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 784\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;y&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        unknown_rank: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Hidden1/kernel/Initializer/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\020\\003\\000\\000d\\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Hidden1/kernel/Initializer/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Hidden1/kernel/Initializer/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.057587556540966034\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Hidden1/kernel/Initializer/truncated_normal/TruncatedNormal&quot;\n  op: &quot;TruncatedNormal&quot;\n  input: &quot;Hidden1/kernel/Initializer/truncated_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 42\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 5\n    }\n  }\n}\nnode {\n  name: &quot;Hidden1/kernel/Initializer/truncated_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;Hidden1/kernel/Initializer/truncated_normal/TruncatedNormal&quot;\n  input: &quot;Hidden1/kernel/Initializer/truncated_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Hidden1/kernel&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Hidden1/kernel/Initializer/truncated_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;Hidden1/kernel/Initializer/truncated_normal/mul&quot;\n  input: &quot;Hidden1/kernel/Initializer/truncated_normal/mean&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Hidden1/kernel&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Hidden1/kernel&quot;\n  op: &quot;VariableV2&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: & ...

# %% [markdown]
# ## Add Batch Normalization

# %% [markdown]
#     run time 160.15829229354858
#     score :  0.9071
# if take a look, the

# %%
reset_graph ()

# %%
from functools import partial

X = tf.placeholder (tf.float32, shape = (None, N_feature), name = 'X')
y = tf.placeholder (tf.int32, shape = (None), name = 'y')

with tf.name_scope ('DNN_chapter11_8'):
    he_init = tf.contrib.layers.variance_scaling_initializer ()
    training = tf.placeholder_with_default (False, shape = (), name = 'training')
    Batch_norm_layer = partial (tf.layers.batch_normalization, training = training, momentum = 0.9)
    hidden1 = tf.layers.dense (X, n_neurons, kernel_initializer = he_init, name = 'Hidden1')
    batch_h1 = Batch_norm_layer (hidden1)
    batch_h1_act = tf.nn.elu (batch_h1)
    hidden2 = tf.layers.dense (batch_h1_act, n_neurons, kernel_initializer = he_init, name = 'Hidden2')
    batch_h2 = Batch_norm_layer (hidden2)
    batch_h2_act = tf.nn.elu (batch_h2)
    hidden3 = tf.layers.dense (batch_h2_act, n_neurons, kernel_initializer = he_init, name = 'Hidden3')
    batch_h3 = Batch_norm_layer (hidden3)
    batch_h3_act = tf.nn.elu (batch_h3)
    hidden4 = tf.layers.dense (batch_h3_act, n_neurons, kernel_initializer = he_init, name = 'Hidden4')
    batch_h4 = Batch_norm_layer (hidden4)
    batch_h4_act = tf.nn.elu (batch_h4)
    hidden5 = tf.layers.dense (batch_h4_act, n_neurons, kernel_initializer = he_init, name = 'Hidden5')
    batch_h5 = Batch_norm_layer (hidden5)
    batch_h5_act = tf.nn.elu (batch_h5)
    y_predit_before_norm = tf.layers.dense (batch_h5_act, n_output, kernel_initializer = he_init, name = 'Output')
    y_predit = Batch_norm_layer (y_predit_before_norm)

with tf.name_scope ('loss'):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=y_predit)
    loss = tf.reduce_mean(xentropy, name="loss")

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(y_predit, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()
saver = tf.train.Saver()
extra_update_ops = tf.get_collection (tf.GraphKeys.UPDATE_OPS)
n_steps = 20
batch_size = 32
data_size = X_train.shape[0]
n_batch = int (np.ceil (data_size / batch_size))

with tf.Session() as sess:
    init.run()
    total_start_time = time.time()
    for step in range (n_steps):
        start_time = time.time ()
        for i_batch in range (n_batch):
            start = i_batch * batch_size
            if i_batch != n_batch - 1:
                end = start + batch_size
            else:
                end = data_size
            sess.run ([training_op, training], feed_dict = {training: True , X: X_train[start: end], y: y_train[start: end]})
        train_score = accuracy.eval (feed_dict = {X: X_train[start: end], y: y_train[start: end]})
        loss_val, validation_score = sess.run([loss, accuracy], feed_dict = {X: X_validation, y:y_validation})
        end_time = time.time ()
        run_time = end_time - start_time
        print ('At step ', step, 'the train_score is ', train_score, 'the validation score is ', validation_score, 'this cost', run_time)
    total_end_time = time.time ()
    print ('Run', n_steps,  'steps total process time is',  total_end_time - total_start_time)
    accuracy_val = accuracy.eval (feed_dict = {X: X_test, y: y_test})
    print ('the test set accuracy is', accuracy_val)
# Out:
# At step  0 the train_score is  0.6666667 the validation score is  0.6212 this cost 8.404719829559326
# At step  1 the train_score is  0.75 the validation score is  0.6988 this cost 8.101255416870117
# At step  2 the train_score is  0.75 the validation score is  0.742 this cost 7.96158504486084
# At step  3 the train_score is  0.75 the validation score is  0.7704 this cost 8.01939868927002
# At step  4 the train_score is  0.7916667 the validation score is  0.7946 this cost 7.948190927505493
# At step  5 the train_score is  0.875 the validation score is  0.815 this cost 7.954518795013428
# At step  6 the train_score is  0.875 the validation score is  0.8298 this cost 7.954497814178467
# At step  7 the train_score is  0.875 the validation score is  0.8464 this cost 7.980224847793579
# At step  8 the train_score is  0.9166667 the validation score is  0.8574 this cost 7.987247943878174
# At step  9 the train_score is  0.9166667 the validation score is  0.866 this cost 7.969722747802734
# At step  10 the train_score is  0.9166667 the validation score is  0.8748 this cost 7.979595422744751
# At step  11 the train_score is  0.9166667 the validation score is  0.8816 this cost 7.957237720489502
# At step  12 the train_score is  0.9166667 the validation score is  0.8866 this cost 7.938660621643066
# At step  13 the train_score is  0.9166667 the validation score is  0.8904 this cost 7.942811727523804
# At step  14 the train_score is  0.9583333 the validation score is  0.8922 this cost 7.969576358795166
# At step  15 the train_score is  0.9583333 the validation score is  0.8954 this cost 7.983825445175171
# At step  16 the train_score is  0.9583333 the validation score is  0.8996 this cost 8.079065799713135
# At step  17 the train_score is  0.9583333 the validation score is  0.9028 this cost 8.054481744766235
# At step  18 the train_score is  0.9583333 the validation score is  0.907 this cost 8.018620491027832
# At step  19 the train_score is  0.9583333 the validation score is  0.9096 this cost 7.949056386947632
# Run 20 steps total process time is 160.15829229354858
# the test set accuracy is 0.9071

# %% [markdown]
# ## Add gradiant clip

# %%
reset_graph ()

# %%
N_feature = X_test.shape[1]
n_layers = 5
n_neurons = 100
learning_rate = 0.01
n_output = 10

X = tf.placeholder (tf.float32, shape = (None, N_feature), name = 'X')
y = tf.placeholder (tf.int32, shape = (None), name = 'y')

with tf.name_scope ('DNN_chapter11_8'):
    he_init = tf.contrib.layers.variance_scaling_initializer ()
    inputs = X
    for layer in range (n_layers):
        inputs = tf.layers.dense (inputs, n_neurons, activation = tf.nn.elu, kernel_initializer = he_init, name="hidden%d" % (layer + 1))
    y_predit = tf.layers.dense (inputs, n_output, kernel_initializer = he_init, name = 'output')
    y_proba = tf.nn.softmax(y_predit, name="Y_proba")
with tf.name_scope ('loss'):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=y_predit)
    loss = tf.reduce_mean(xentropy, name="loss")

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(y_predit, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()
saver = tf.train.Saver()
extra_update_ops = tf.get_collection (tf.GraphKeys.UPDATE_OPS)
n_steps = 20
batch_size = 32
data_size = X_train.shape[0]
n_batch = int (np.ceil (data_size / batch_size))

# %%
with tf.Session() as sess:
    init.run()
    total_start_time = time.time()
    for step in range (n_steps):
        start_time = time.time ()
        for i_batch in range (n_batch):
            start = i_batch * batch_size
            if i_batch != n_batch - 1:
                end = start + batch_size
            else:
                end = data_size
            sess.run (training_op, feed_dict = {X: X_train[start: end], y: y_train[start: end]})
        train_score = accuracy.eval (feed_dict = {X: X_train[start: end], y: y_train[start: end]})
        loss_val, validation_score = sess.run([loss, accuracy], feed_dict = {X: X_validation, y:y_validation})
        end_time = time.time ()
        run_time = end_time - start_time
        print ('At step ', step, 'the train_score is ', train_score, 'the validation score is ', validation_score, 'this cost', run_time)
    total_end_time = time.time ()
    print ('Run', n_steps,  'steps total process time is',  total_end_time - total_start_time)
    accuracy_val = accuracy.eval (feed_dict = {X: X_test, y: y_test})
    print ('the test set accuracy is', accuracy_val)
# Out:
# At step  0 the train_score is  1.0 the validation score is  0.937 this cost 4.546437501907349
# At step  1 the train_score is  1.0 the validation score is  0.953 this cost 4.477341413497925
# At step  2 the train_score is  1.0 the validation score is  0.9614 this cost 4.481766939163208
# At step  3 the train_score is  1.0 the validation score is  0.964 this cost 4.4571146965026855
# At step  4 the train_score is  1.0 the validation score is  0.9668 this cost 4.478733777999878
# At step  5 the train_score is  1.0 the validation score is  0.9684 this cost 4.53850245475769
# At step  6 the train_score is  1.0 the validation score is  0.9694 this cost 4.448465585708618
# At step  7 the train_score is  1.0 the validation score is  0.9714 this cost 4.465167045593262
# At step  8 the train_score is  1.0 the validation score is  0.9732 this cost 4.489724397659302
# At step  9 the train_score is  1.0 the validation score is  0.9746 this cost 4.464863061904907
# At step  10 the train_score is  1.0 the validation score is  0.975 this cost 4.491323471069336
# At step  11 the train_score is  1.0 the validation score is  0.9754 this cost 4.469268798828125
# At step  12 the train_score is  1.0 the validation score is  0.9754 this cost 4.476378440856934
# At step  13 the train_score is  1.0 the validation score is  0.9758 this cost 4.454278230667114
# At step  14 the train_score is  1.0 the validation score is  0.9758 this cost 4.460477113723755
# At step  15 the train_score is  1.0 the validation score is  0.976 this cost 4.477837562561035
# At step  16 the train_score is  1.0 the validation score is  0.9762 this cost 4.492745637893677
# At step  17 the train_score is  1.0 the validation score is  0.9762 this cost 4.479362726211548
# At step  18 the train_score is  1.0 the validation score is  0.9764 this cost 4.4772374629974365
# At step  19 the train_score is  1.0 the validation score is  0.9758 this cost 4.4904561042785645
# Run 20 steps total process time is 89.62347483634949
# the test set accuracy is 0.9735
